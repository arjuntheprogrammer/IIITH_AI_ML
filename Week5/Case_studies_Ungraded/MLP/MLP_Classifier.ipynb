# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint

# %% [markdown]
# ###Not for Grading

# %% [markdown]
# ####Classification using MLP

# %% [markdown]
# The objective of this case study is to understand classification i.e., if the price of the house is low (0) or high (1) using Multilayer perceptron.  The package used here is [PyTorch](https://pytorch.org/).

# %% [markdown]
# ##*We will see more on PyTorch in the upcoming sessions.*

# %% [markdown]
# #### Setup Steps

# %%
#@title Please enter your registration id to start: (e.g. P181900101) { run: "auto", display-mode: "form" }
Id = "P18_test" #@param {type:"string"}

# %%
#@title Please enter your password (normally your phone number) to continue: { run: "auto", display-mode: "form" }
password = "912345678" #@param {type:"string"}

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython

ipython = get_ipython()
  
notebook="M1W2_CS_5_MLP_Classifier" #name of the notebook
Answer = "Ungraded"
def setup():
    ipython.magic("sx pip3 install torch")  
    from IPython.display import HTML, display
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():
    
    ipython.magic("notebook -e "+ notebook + ".ipynb")
    
    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword()}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:        
        print(r["err"])
        return None        
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getAnswer() and getComplexity() and getAdditional() and getConcepts():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional, 
              "concepts" : Concepts, "record_id" : submission_id, 
              "answer" : Answer, "id" : Id, "file_hash" : file_hash,
              "notebook" : notebook}

      r = requests.post(url, data = data)
      r = json.loads(r.text)
      print("Your submission is successful.")
      print("Ref Id:", submission_id)
      print("Date of submission: ", r["date"])
      print("Time of submission: ", r["time"])
      print("View your submissions: https://iiith-aiml.talentsprint.com/notebook_submissions")
      print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
      return submission_id
    else: submission_id
    

def getAdditional():
  try:
    if Additional: return Additional      
    else: raise NameError('')
  except NameError:
    print ("Please answer Additional Question")
    return None

def getComplexity():
  try:
    return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None
  
def getConcepts():
  try:
    return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None

def getAnswer():
  try:
    return Answer
  except NameError:
    print ("Please answer Question")
    return None

def getId():
  try: 
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup 
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()
    from IPython.display import HTML
    HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id))
  
else:
  print ("Please complete Id and Password cells before running setup")
# Out:
# <script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId=P18_test&recordId=21353"></script>
# Setup completed successfully

# %% [markdown]
# ### Importing required packages

# %%
# Importing required Packages
import matplotlib.pyplot as plt
import numpy as np
import  torch
from torch import nn
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ###The attributes of related House price are stored in "X" as features and the House price whether it is low (0) or high (1) are stored in "y" as labels.

# %%
X = np.array([[3, 2000, 90], [2, 800, 143], [2, 850, 167], [1, 550, 267], [4, 2000, 396]])
y = np.array([1, 0, 0, 0 , 1])

# %% [markdown]
# ###Standard scaling the features "X"

# %%
ss = StandardScaler()
ss.fit(X)
X = ss.transform(X)
X
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[ 0.58834841,  1.20863526, -1.13296108],
#        [-0.39223227, -0.6997362 , -0.64318182],
#        [-0.39223227, -0.62022073, -0.42139498],
#        [-1.37281295, -1.09731359,  0.50271682],
#        [ 1.56892908,  1.20863526,  1.69482106]])

# %% [markdown]
# ###Defining the model for Linear Classification with MLP using PyTorch's nn.Module

# %%
class LinearClassificationModel(nn.Module):

    def __init__(self, input_dim, output_dim):
        super(LinearClassificationModel, self).__init__() 
        # Calling Super Class's constructor
        self.linear1 = nn.Linear(input_dim, 4)
        self.linear2 = nn.Linear(4, output_dim)
        self.activation= nn.Sigmoid()
        # nn.Linear is defined in nn.Module

    def forward(self, x):
        # Here the forward pass is simply a linear function
        #print(x.size())
        out = self.linear1(x)
        out = self.activation(out)
        out = self.linear2(out)
        out = self.activation(out)
        return out

input_dim = 3
output_dim = 1

# %% [markdown]
# ###The LinearClassificationModel() is saved in model below

# %%
model = LinearClassificationModel(input_dim,output_dim) 
criterion = nn.MSELoss() 
l_rate = 0.01  #Learning Rate
optimiser = torch.optim.SGD(model.parameters(), lr = l_rate) #Stochastic Gradient Descent
epochs = 5000  #number of epochs

# %% [markdown]
# ###Storing the losses in a list for the prescribed epochs

# %%
losses = []
for epoch in range(epochs):
#increase the number of epochs by 1 every time
    epoch +=1
  #inputs and labels are stored in a particular format as per the model
    inputs = torch.from_numpy(X.astype(np.float32))
    labels = torch.from_numpy(y.astype(np.float32))
    labels = labels.type(torch.long)  
    #clear grads as discussed in prev post
    optimiser.zero_grad()
    #forward to get predicted values
    outputs = model.forward(inputs)
    print('outputs: ', outputs)
    print('labels: ', labels)
    print('outputs size: ', outputs.size())
    print('labels size: ', labels.size())
    loss = criterion(outputs,labels.float())
    print('loss:', loss)
    loss.backward()# back props
    optimiser.step()# update the parameters
    print('epoch {}, loss {}'.format(epoch,loss.item()))
    losses.append(loss.item())
    if (epoch-1)%50 == 0:
        for i in model.parameters():
            print(i)
# Out:
# outputs:  tensor([[0.4172],
#         [0.3939],
#         [0.3970],
#         [0.4016],
#         [0.4310]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 1, loss 0.2402609884738922
# Parameter containing:
# tensor([[ 0.3031,  0.0496,  0.4857],
#         [-0.0085, -0.3881,  0.1631],
#         [-0.3224,  0.4472,  0.4752],
#         [ 0.2337,  0.0027, -0.1720]], requires_grad=True)
# Parameter containing:
# tensor([ 0.0202, -0.5109,  0.2001, -0.0194], requires_grad=True)
# Parameter containing:
# tensor([[-0.0164, -0.3377,  0.4146,  0.0719]], requires_grad=True)
# Parameter containing:
# tensor([-0.4975], requires_grad=True)
# outputs:  tensor([[0.4172],
#         [0.3939],
#         [0.3970],
#         [0.4016],
#         [0.4309]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 2, loss 0.24026060104370117
# outputs:  tensor([[0.4172],
#         [0.3939],
#         [0.3969],
#         [0.4016],
#         [0.4309]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 3, loss 0.24026019871234894
# outputs:  tensor([[0.4172],
#         [0.3938],
#         [0.3969],
#         [0.4016],
#         [0.4309]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 4, loss 0.2402598112821579
# outputs:  tensor([[0.4171],
#         [0.3938],
#         [0.3969],
#         [0.4016],
#         [0.4309]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 5, loss 0.24025942385196686
# outputs:  tensor([[0.4171],
#         [0.3938],
#         [0.3969],
#         [0.4015],
#         [0.4308]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 6, loss 0.24025903642177582
# outputs:  tensor([[0.4171],
#         [0.3938],
#         [0.3969],
#         [0.4015],
#         [0.4308]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 7, loss 0.24025866389274597
# outputs:  tensor([[0.4171],
#         [0.3938],
#         [0.3968],
#         [0.4015],
#         [0.4308]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 8, loss 0.24025827646255493
# outputs:  tensor([[0.4171],
#         [0.3938],
#         [0.3968],
#         [0.4015],
#         [0.4308]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 9, loss 0.24025790393352509
# outputs:  tensor([[0.4170],
#         [0.3937],
#         [0.3968],
#         [0.4015],
#         [0.4308]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 10, loss 0.24025751650333405
# outputs:  tensor([[0.4170],
#         [0.3937],
#         [0.3968],
#         [0.4014],
#         [0.4307]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 11, loss 0.2402571439743042
# outputs:  tensor([[0.4170],
#         [0.3937],
#         [0.3968],
#         [0.4014],
#         [0.4307]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 12, loss 0.24025677144527435
# outputs:  tensor([[0.4170],
#         [0.3937],
#         [0.3967],
#         [0.4014],
#         [0.4307]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 13, loss 0.2402563989162445
# outputs:  tensor([[0.4170],
#         [0.3937],
#         [0.3967],
#         [0.4014],
#         [0.4307]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 14, loss 0.24025602638721466
# outputs:  tensor([[0.4169],
#         [0.3936],
#         [0.3967],
#         [0.4014],
#         [0.4306]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 15, loss 0.24025565385818481
# outputs:  tensor([[0.4169],
#         [0.3936],
#         [0.3967],
#         [0.4013],
#         [0.4306]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 16, loss 0.24025528132915497
# outputs:  tensor([[0.4169],
#         [0.3936],
#         [0.3967],
#         [0.4013],
#         [0.4306]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 17, loss 0.24025492370128632
# outputs:  tensor([[0.4169],
#         [0.3936],
#         [0.3967],
#         [0.4013],
#         [0.4306]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 18, loss 0.24025455117225647
# outputs:  tensor([[0.4169],
#         [0.3936],
#         [0.3966],
#         [0.4013],
#         [0.4305]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 19, loss 0.24025419354438782
# outputs:  tensor([[0.4168],
#         [0.3936],
#         [0.3966],
#         [0.4013],
#         [0.4305]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 20, loss 0.24025382101535797
# outputs:  tensor([[0.4168],
#         [0.3935],
#         [0.3966],
#         [0.4013],
#         [0.4305]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 21, loss 0.24025346338748932
# outputs:  tensor([[0.4168],
#         [0.3935],
#         [0.3966],
#         [0.4012],
#         [0.4305]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 22, loss 0.24025310575962067
# outputs:  tensor([[0.4168],
#         [0.3935],
#         [0.3966],
#         [0.4012],
#         [0.4304]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 23, loss 0.24025274813175201
# outputs:  tensor([[0.4168],
#         [0.3935],
#         [0.3965],
#         [0.4012],
#         [0.4304]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 24, loss 0.24025239050388336
# outputs:  tensor([[0.4167],
#         [0.3935],
#         [0.3965],
#         [0.4012],
#         [0.4304]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 25, loss 0.2402520328760147
# outputs:  tensor([[0.4167],
#         [0.3934],
#         [0.3965],
#         [0.4012],
#         [0.4304]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 26, loss 0.24025167524814606
# outputs:  tensor([[0.4167],
#         [0.3934],
#         [0.3965],
#         [0.4011],
#         [0.4303]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 27, loss 0.2402513325214386
# outputs:  tensor([[0.4167],
#         [0.3934],
#         [0.3965],
#         [0.4011],
#         [0.4303]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 28, loss 0.24025097489356995
# outputs:  tensor([[0.4167],
#         [0.3934],
#         [0.3965],
#         [0.4011],
#         [0.4303]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 29, loss 0.2402506321668625
# outputs:  tensor([[0.4167],
#         [0.3934],
#         [0.3964],
#         [0.4011],
#         [0.4303]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2403, grad_fn=<MseLossBackward>)
# epoch 30, loss 0.24025028944015503
# outputs:  tensor([[0.4166],
#         [0.3934],
#         [0.3964],
#         [0.4011],
#         [0.4302]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 31, loss 0.24024994671344757
# outputs:  tensor([[0.4166],
#         [0.3933],
#         [0.3964],
#         [0.4010],
#         [0.4302]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 32, loss 0.24024958908557892
# outputs:  tensor([[0.4166],
#         [0.3933],
#         [0.3964],
#         [0.4010],
#         [0.4302]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 33, loss 0.24024924635887146
# outputs:  tensor([[0.4166],
#         [0.3933],
#         [0.3964],
#         [0.4010],
#         [0.4302]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 34, loss 0.2402489185333252
# outputs:  tensor([[0.4166],
#         [0.3933],
#         [0.3964],
#         [0.4010],
#         [0.4302]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 35, loss 0.24024857580661774
# outputs:  tensor([[0.4165],
#         [0.3933],
#         [0.3963],
#         [0.4010],
#         [0.4301]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 36, loss 0.24024823307991028
# outputs:  tensor([[0.4165],
#         [0.3933],
#         [0.3963],
#         [0.4010],
#         [0.4301]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 37, loss 0.240247905254364
# outputs:  tensor([[0.4165],
#         [0.3932],
#         [0.3963],
#         [0.4009],
#         [0.4301]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 38, loss 0.24024756252765656
# outputs:  tensor([[0.4165],
#         [0.3932],
#         [0.3963],
#         [0.4009],
#         [0.4301]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 39, loss 0.2402472198009491
# outputs:  tensor([[0.4165],
#         [0.3932],
#         [0.3963],
#         [0.4009],
#         [0.4300]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 40, loss 0.24024689197540283
# outputs:  tensor([[0.4164],
#         [0.3932],
#         [0.3962],
#         [0.4009],
#         [0.4300]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 41, loss 0.24024656414985657
# outputs:  tensor([[0.4164],
#         [0.3932],
#         [0.3962],
#         [0.4009],
#         [0.4300]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 42, loss 0.2402462363243103
# outputs:  tensor([[0.4164],
#         [0.3932],
#         [0.3962],
#         [0.4008],
#         [0.4300]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 43, loss 0.24024590849876404
# outputs:  tensor([[0.4164],
#         [0.3931],
#         [0.3962],
#         [0.4008],
#         [0.4299]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 44, loss 0.24024558067321777
# outputs:  tensor([[0.4164],
#         [0.3931],
#         [0.3962],
#         [0.4008],
#         [0.4299]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 45, loss 0.2402452528476715
# outputs:  tensor([[0.4164],
#         [0.3931],
#         [0.3962],
#         [0.4008],
#         [0.4299]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 46, loss 0.24024492502212524
# outputs:  tensor([[0.4163],
#         [0.3931],
#         [0.3961],
#         [0.4008],
#         [0.4299]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 47, loss 0.24024461209774017
# outputs:  tensor([[0.4163],
#         [0.3931],
#         [0.3961],
#         [0.4008],
#         [0.4299]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 48, loss 0.2402442842721939
# outputs:  tensor([[0.4163],
#         [0.3931],
#         [0.3961],
#         [0.4007],
#         [0.4298]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 49, loss 0.24024397134780884
# outputs:  tensor([[0.4163],
#         [0.3930],
#         [0.3961],
#         [0.4007],
#         [0.4298]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 50, loss 0.24024364352226257
# outputs:  tensor([[0.4163],
#         [0.3930],
#         [0.3961],
#         [0.4007],
#         [0.4298]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 51, loss 0.2402433305978775
# Parameter containing:
# tensor([[ 0.3031,  0.0496,  0.4857],
#         [-0.0083, -0.3879,  0.1633],
#         [-0.3226,  0.4469,  0.4751],
#         [ 0.2336,  0.0026, -0.1721]], requires_grad=True)
# Parameter containing:
# tensor([ 0.0202, -0.5108,  0.1999, -0.0194], requires_grad=True)
# Parameter containing:
# tensor([[-0.0178, -0.3382,  0.4133,  0.0709]], requires_grad=True)
# Parameter containing:
# tensor([-0.4994], requires_grad=True)
# outputs:  tensor([[0.4162],
#         [0.3930],
#         [0.3961],
#         [0.4007],
#         [0.4298]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 52, loss 0.24024301767349243
# outputs:  tensor([[0.4162],
#         [0.3930],
#         [0.3960],
#         [0.4007],
#         [0.4297]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 53, loss 0.24024270474910736
# outputs:  tensor([[0.4162],
#         [0.3930],
#         [0.3960],
#         [0.4007],
#         [0.4297]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 54, loss 0.2402423918247223
# outputs:  tensor([[0.4162],
#         [0.3930],
#         [0.3960],
#         [0.4006],
#         [0.4297]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 55, loss 0.24024207890033722
# outputs:  tensor([[0.4162],
#         [0.3929],
#         [0.3960],
#         [0.4006],
#         [0.4297]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 56, loss 0.24024176597595215
# outputs:  tensor([[0.4162],
#         [0.3929],
#         [0.3960],
#         [0.4006],
#         [0.4297]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 57, loss 0.24024146795272827
# outputs:  tensor([[0.4161],
#         [0.3929],
#         [0.3960],
#         [0.4006],
#         [0.4296]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 58, loss 0.2402411550283432
# outputs:  tensor([[0.4161],
#         [0.3929],
#         [0.3959],
#         [0.4006],
#         [0.4296]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 59, loss 0.24024085700511932
# outputs:  tensor([[0.4161],
#         [0.3929],
#         [0.3959],
#         [0.4005],
#         [0.4296]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 60, loss 0.24024054408073425
# outputs:  tensor([[0.4161],
#         [0.3929],
#         [0.3959],
#         [0.4005],
#         [0.4296]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 61, loss 0.24024024605751038
# outputs:  tensor([[0.4161],
#         [0.3928],
#         [0.3959],
#         [0.4005],
#         [0.4295]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 62, loss 0.2402399331331253
# outputs:  tensor([[0.4161],
#         [0.3928],
#         [0.3959],
#         [0.4005],
#         [0.4295]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 63, loss 0.24023963510990143
# outputs:  tensor([[0.4160],
#         [0.3928],
#         [0.3959],
#         [0.4005],
#         [0.4295]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 64, loss 0.24023933708667755
# outputs:  tensor([[0.4160],
#         [0.3928],
#         [0.3958],
#         [0.4005],
#         [0.4295]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 65, loss 0.24023903906345367
# outputs:  tensor([[0.4160],
#         [0.3928],
#         [0.3958],
#         [0.4004],
#         [0.4295]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 66, loss 0.2402387410402298
# outputs:  tensor([[0.4160],
#         [0.3928],
#         [0.3958],
#         [0.4004],
#         [0.4294]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 67, loss 0.24023844301700592
# outputs:  tensor([[0.4160],
#         [0.3927],
#         [0.3958],
#         [0.4004],
#         [0.4294]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 68, loss 0.24023814499378204
# outputs:  tensor([[0.4159],
#         [0.3927],
#         [0.3958],
#         [0.4004],
#         [0.4294]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 69, loss 0.24023786187171936
# outputs:  tensor([[0.4159],
#         [0.3927],
#         [0.3958],
#         [0.4004],
#         [0.4294]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 70, loss 0.24023756384849548
# outputs:  tensor([[0.4159],
#         [0.3927],
#         [0.3957],
#         [0.4004],
#         [0.4294]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 71, loss 0.2402372658252716
# outputs:  tensor([[0.4159],
#         [0.3927],
#         [0.3957],
#         [0.4003],
#         [0.4293]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 72, loss 0.24023698270320892
# outputs:  tensor([[0.4159],
#         [0.3927],
#         [0.3957],
#         [0.4003],
#         [0.4293]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 73, loss 0.24023669958114624
# outputs:  tensor([[0.4159],
#         [0.3927],
#         [0.3957],
#         [0.4003],
#         [0.4293]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 74, loss 0.24023641645908356
# outputs:  tensor([[0.4158],
#         [0.3926],
#         [0.3957],
#         [0.4003],
#         [0.4293]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 75, loss 0.24023611843585968
# outputs:  tensor([[0.4158],
#         [0.3926],
#         [0.3957],
#         [0.4003],
#         [0.4292]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 76, loss 0.240235835313797
# outputs:  tensor([[0.4158],
#         [0.3926],
#         [0.3957],
#         [0.4003],
#         [0.4292]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 77, loss 0.24023555219173431
# outputs:  tensor([[0.4158],
#         [0.3926],
#         [0.3956],
#         [0.4002],
#         [0.4292]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 78, loss 0.24023528397083282
# outputs:  tensor([[0.4158],
#         [0.3926],
#         [0.3956],
#         [0.4002],
#         [0.4292]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 79, loss 0.24023498594760895
# outputs:  tensor([[0.4158],
#         [0.3926],
#         [0.3956],
#         [0.4002],
#         [0.4292]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 80, loss 0.24023470282554626
# outputs:  tensor([[0.4157],
#         [0.3925],
#         [0.3956],
#         [0.4002],
#         [0.4291]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 81, loss 0.24023443460464478
# outputs:  tensor([[0.4157],
#         [0.3925],
#         [0.3956],
#         [0.4002],
#         [0.4291]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 82, loss 0.2402341514825821
# outputs:  tensor([[0.4157],
#         [0.3925],
#         [0.3956],
#         [0.4002],
#         [0.4291]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 83, loss 0.2402338832616806
# outputs:  tensor([[0.4157],
#         [0.3925],
#         [0.3955],
#         [0.4001],
#         [0.4291]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 84, loss 0.24023360013961792
# outputs:  tensor([[0.4157],
#         [0.3925],
#         [0.3955],
#         [0.4001],
#         [0.4291]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 85, loss 0.24023333191871643
# outputs:  tensor([[0.4157],
#         [0.3925],
#         [0.3955],
#         [0.4001],
#         [0.4290]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 86, loss 0.24023304879665375
# outputs:  tensor([[0.4156],
#         [0.3925],
#         [0.3955],
#         [0.4001],
#         [0.4290]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 87, loss 0.24023279547691345
# outputs:  tensor([[0.4156],
#         [0.3924],
#         [0.3955],
#         [0.4001],
#         [0.4290]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 88, loss 0.24023252725601196
# outputs:  tensor([[0.4156],
#         [0.3924],
#         [0.3955],
#         [0.4001],
#         [0.4290]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 89, loss 0.24023224413394928
# outputs:  tensor([[0.4156],
#         [0.3924],
#         [0.3954],
#         [0.4001],
#         [0.4290]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 90, loss 0.2402319759130478
# outputs:  tensor([[0.4156],
#         [0.3924],
#         [0.3954],
#         [0.4000],
#         [0.4289]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 91, loss 0.2402317076921463
# outputs:  tensor([[0.4156],
#         [0.3924],
#         [0.3954],
#         [0.4000],
#         [0.4289]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 92, loss 0.2402314394712448
# outputs:  tensor([[0.4155],
#         [0.3924],
#         [0.3954],
#         [0.4000],
#         [0.4289]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 93, loss 0.24023117125034332
# outputs:  tensor([[0.4155],
#         [0.3923],
#         [0.3954],
#         [0.4000],
#         [0.4289]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 94, loss 0.24023091793060303
# outputs:  tensor([[0.4155],
#         [0.3923],
#         [0.3954],
#         [0.4000],
#         [0.4289]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 95, loss 0.24023064970970154
# outputs:  tensor([[0.4155],
#         [0.3923],
#         [0.3954],
#         [0.4000],
#         [0.4288]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 96, loss 0.24023039638996124
# outputs:  tensor([[0.4155],
#         [0.3923],
#         [0.3953],
#         [0.3999],
#         [0.4288]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 97, loss 0.24023012816905975
# outputs:  tensor([[0.4155],
#         [0.3923],
#         [0.3953],
#         [0.3999],
#         [0.4288]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 98, loss 0.24022987484931946
# outputs:  tensor([[0.4154],
#         [0.3923],
#         [0.3953],
#         [0.3999],
#         [0.4288]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 99, loss 0.24022960662841797
# outputs:  tensor([[0.4154],
#         [0.3923],
#         [0.3953],
#         [0.3999],
#         [0.4288]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 100, loss 0.24022935330867767
# outputs:  tensor([[0.4154],
#         [0.3922],
#         [0.3953],
#         [0.3999],
#         [0.4287]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 101, loss 0.24022909998893738
# Parameter containing:
# tensor([[ 0.3031,  0.0496,  0.4857],
#         [-0.0081, -0.3876,  0.1634],
#         [-0.3229,  0.4466,  0.4750],
#         [ 0.2336,  0.0026, -0.1721]], requires_grad=True)
# Parameter containing:
# tensor([ 0.0202, -0.5107,  0.1998, -0.0195], requires_grad=True)
# Parameter containing:
# tensor([[-0.0190, -0.3386,  0.4121,  0.0700]], requires_grad=True)
# Parameter containing:
# tensor([-0.5010], requires_grad=True)
# outputs:  tensor([[0.4154],
#         [0.3922],
#         [0.3953],
#         [0.3999],
#         [0.4287]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 102, loss 0.24022884666919708
# outputs:  tensor([[0.4154],
#         [0.3922],
#         [0.3952],
#         [0.3998],
#         [0.4287]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 103, loss 0.2402285933494568
# outputs:  tensor([[0.4154],
#         [0.3922],
#         [0.3952],
#         [0.3998],
#         [0.4287]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 104, loss 0.2402283400297165
# outputs:  tensor([[0.4154],
#         [0.3922],
#         [0.3952],
#         [0.3998],
#         [0.4287]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 105, loss 0.2402280867099762
# outputs:  tensor([[0.4153],
#         [0.3922],
#         [0.3952],
#         [0.3998],
#         [0.4286]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 106, loss 0.2402278482913971
# outputs:  tensor([[0.4153],
#         [0.3922],
#         [0.3952],
#         [0.3998],
#         [0.4286]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 107, loss 0.2402275949716568
# outputs:  tensor([[0.4153],
#         [0.3921],
#         [0.3952],
#         [0.3998],
#         [0.4286]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 108, loss 0.2402273416519165
# outputs:  tensor([[0.4153],
#         [0.3921],
#         [0.3952],
#         [0.3998],
#         [0.4286]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 109, loss 0.2402270883321762
# outputs:  tensor([[0.4153],
#         [0.3921],
#         [0.3951],
#         [0.3997],
#         [0.4286]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 110, loss 0.2402268499135971
# outputs:  tensor([[0.4153],
#         [0.3921],
#         [0.3951],
#         [0.3997],
#         [0.4285]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 111, loss 0.240226611495018
# outputs:  tensor([[0.4152],
#         [0.3921],
#         [0.3951],
#         [0.3997],
#         [0.4285]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 112, loss 0.2402263581752777
# outputs:  tensor([[0.4152],
#         [0.3921],
#         [0.3951],
#         [0.3997],
#         [0.4285]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 113, loss 0.2402261197566986
# outputs:  tensor([[0.4152],
#         [0.3921],
#         [0.3951],
#         [0.3997],
#         [0.4285]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 114, loss 0.2402258664369583
# outputs:  tensor([[0.4152],
#         [0.3920],
#         [0.3951],
#         [0.3997],
#         [0.4285]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 115, loss 0.2402256280183792
# outputs:  tensor([[0.4152],
#         [0.3920],
#         [0.3951],
#         [0.3996],
#         [0.4284]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 116, loss 0.2402254045009613
# outputs:  tensor([[0.4152],
#         [0.3920],
#         [0.3950],
#         [0.3996],
#         [0.4284]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 117, loss 0.2402251660823822
# outputs:  tensor([[0.4151],
#         [0.3920],
#         [0.3950],
#         [0.3996],
#         [0.4284]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 118, loss 0.2402249127626419
# outputs:  tensor([[0.4151],
#         [0.3920],
#         [0.3950],
#         [0.3996],
#         [0.4284]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 119, loss 0.2402246594429016
# outputs:  tensor([[0.4151],
#         [0.3920],
#         [0.3950],
#         [0.3996],
#         [0.4284]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 120, loss 0.2402244508266449
# outputs:  tensor([[0.4151],
#         [0.3920],
#         [0.3950],
#         [0.3996],
#         [0.4283]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 121, loss 0.2402241975069046
# outputs:  tensor([[0.4151],
#         [0.3919],
#         [0.3950],
#         [0.3996],
#         [0.4283]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 122, loss 0.2402239739894867
# outputs:  tensor([[0.4151],
#         [0.3919],
#         [0.3950],
#         [0.3995],
#         [0.4283]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 123, loss 0.2402237355709076
# outputs:  tensor([[0.4151],
#         [0.3919],
#         [0.3949],
#         [0.3995],
#         [0.4283]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 124, loss 0.24022351205348969
# outputs:  tensor([[0.4150],
#         [0.3919],
#         [0.3949],
#         [0.3995],
#         [0.4283]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 125, loss 0.24022327363491058
# outputs:  tensor([[0.4150],
#         [0.3919],
#         [0.3949],
#         [0.3995],
#         [0.4282]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 126, loss 0.24022305011749268
# outputs:  tensor([[0.4150],
#         [0.3919],
#         [0.3949],
#         [0.3995],
#         [0.4282]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 127, loss 0.24022281169891357
# outputs:  tensor([[0.4150],
#         [0.3919],
#         [0.3949],
#         [0.3995],
#         [0.4282]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 128, loss 0.24022258818149567
# outputs:  tensor([[0.4150],
#         [0.3918],
#         [0.3949],
#         [0.3995],
#         [0.4282]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 129, loss 0.24022234976291656
# outputs:  tensor([[0.4150],
#         [0.3918],
#         [0.3949],
#         [0.3994],
#         [0.4282]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 130, loss 0.24022212624549866
# outputs:  tensor([[0.4150],
#         [0.3918],
#         [0.3948],
#         [0.3994],
#         [0.4281]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 131, loss 0.24022190272808075
# outputs:  tensor([[0.4149],
#         [0.3918],
#         [0.3948],
#         [0.3994],
#         [0.4281]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 132, loss 0.24022167921066284
# outputs:  tensor([[0.4149],
#         [0.3918],
#         [0.3948],
#         [0.3994],
#         [0.4281]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 133, loss 0.24022145569324493
# outputs:  tensor([[0.4149],
#         [0.3918],
#         [0.3948],
#         [0.3994],
#         [0.4281]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 134, loss 0.24022123217582703
# outputs:  tensor([[0.4149],
#         [0.3918],
#         [0.3948],
#         [0.3994],
#         [0.4281]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 135, loss 0.24022100865840912
# outputs:  tensor([[0.4149],
#         [0.3918],
#         [0.3948],
#         [0.3994],
#         [0.4281]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 136, loss 0.2402208000421524
# outputs:  tensor([[0.4149],
#         [0.3917],
#         [0.3948],
#         [0.3993],
#         [0.4280]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 137, loss 0.2402205765247345
# outputs:  tensor([[0.4148],
#         [0.3917],
#         [0.3947],
#         [0.3993],
#         [0.4280]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 138, loss 0.2402203381061554
# outputs:  tensor([[0.4148],
#         [0.3917],
#         [0.3947],
#         [0.3993],
#         [0.4280]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 139, loss 0.24022012948989868
# outputs:  tensor([[0.4148],
#         [0.3917],
#         [0.3947],
#         [0.3993],
#         [0.4280]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 140, loss 0.24021992087364197
# outputs:  tensor([[0.4148],
#         [0.3917],
#         [0.3947],
#         [0.3993],
#         [0.4280]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 141, loss 0.24021971225738525
# outputs:  tensor([[0.4148],
#         [0.3917],
#         [0.3947],
#         [0.3993],
#         [0.4279]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 142, loss 0.24021947383880615
# outputs:  tensor([[0.4148],
#         [0.3917],
#         [0.3947],
#         [0.3993],
#         [0.4279]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 143, loss 0.24021926522254944
# outputs:  tensor([[0.4148],
#         [0.3916],
#         [0.3947],
#         [0.3992],
#         [0.4279]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 144, loss 0.24021905660629272
# outputs:  tensor([[0.4147],
#         [0.3916],
#         [0.3947],
#         [0.3992],
#         [0.4279]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 145, loss 0.240218847990036
# outputs:  tensor([[0.4147],
#         [0.3916],
#         [0.3946],
#         [0.3992],
#         [0.4279]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 146, loss 0.2402186393737793
# outputs:  tensor([[0.4147],
#         [0.3916],
#         [0.3946],
#         [0.3992],
#         [0.4279]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 147, loss 0.24021843075752258
# outputs:  tensor([[0.4147],
#         [0.3916],
#         [0.3946],
#         [0.3992],
#         [0.4278]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 148, loss 0.24021820724010468
# outputs:  tensor([[0.4147],
#         [0.3916],
#         [0.3946],
#         [0.3992],
#         [0.4278]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 149, loss 0.24021799862384796
# outputs:  tensor([[0.4147],
#         [0.3916],
#         [0.3946],
#         [0.3992],
#         [0.4278]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 150, loss 0.24021780490875244
# outputs:  tensor([[0.4147],
#         [0.3916],
#         [0.3946],
#         [0.3991],
#         [0.4278]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2402, grad_fn=<MseLossBackward>)
# epoch 151, loss 0.24021758139133453
# Parameter containing:
# tensor([[ 0.3031,  0.0496,  0.4857],
#         [-0.0079, -0.3874,  0.1636],
#         [-0.3231,  0.4464,  0.4748],
#         [ 0.2335,  0.0025, -0.1721]], requires_grad=True)
# Parameter containing:
# ...
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4950, loss 0.24010580778121948
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4951, loss 0.2401057928800583
# Parameter containing:
# tensor([[ 0.3049,  0.0517,  0.4866],
#         [ 0.0094, -0.3692,  0.1751],
#         [-0.3429,  0.4245,  0.4638],
#         [ 0.2300, -0.0013, -0.1744]], requires_grad=True)
# Parameter containing:
# tensor([ 0.0199, -0.5120,  0.2013, -0.0195], requires_grad=True)
# Parameter containing:
# tensor([[-0.0538, -0.3233,  0.3885,  0.0623]], requires_grad=True)
# Parameter containing:
# tensor([-0.5021], requires_grad=True)
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4952, loss 0.2401057779788971
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4953, loss 0.2401057630777359
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4954, loss 0.2401057630777359
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4955, loss 0.2401057481765747
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4956, loss 0.2401057332754135
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4957, loss 0.2401057332754135
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4958, loss 0.24010571837425232
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4959, loss 0.24010570347309113
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4960, loss 0.24010570347309113
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4961, loss 0.24010568857192993
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4962, loss 0.24010567367076874
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4963, loss 0.24010565876960754
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4964, loss 0.24010564386844635
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4965, loss 0.24010564386844635
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4966, loss 0.24010562896728516
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4967, loss 0.24010562896728516
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4968, loss 0.24010561406612396
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4969, loss 0.24010559916496277
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4970, loss 0.24010559916496277
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4971, loss 0.24010558426380157
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4972, loss 0.2401055544614792
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4973, loss 0.24010556936264038
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4974, loss 0.2401055544614792
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4975, loss 0.2401055544614792
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4976, loss 0.2401055246591568
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4977, loss 0.2401055246591568
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4978, loss 0.2401055097579956
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4979, loss 0.2401054948568344
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4980, loss 0.24010547995567322
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4981, loss 0.24010547995567322
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4982, loss 0.24010546505451202
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4983, loss 0.24010546505451202
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4984, loss 0.24010545015335083
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4985, loss 0.24010543525218964
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4986, loss 0.24010542035102844
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4987, loss 0.24010542035102844
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4988, loss 0.24010540544986725
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4989, loss 0.24010539054870605
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4990, loss 0.24010537564754486
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4991, loss 0.24010537564754486
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4992, loss 0.24010536074638367
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4993, loss 0.24010536074638367
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4994, loss 0.24010534584522247
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4995, loss 0.24010533094406128
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4996, loss 0.24010531604290009
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4997, loss 0.2401053011417389
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4998, loss 0.2401053011417389
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 4999, loss 0.2401052862405777
# outputs:  tensor([[0.4076],
#         [0.3882],
#         [0.3907],
#         [0.3955],
#         [0.4150]], grad_fn=<SigmoidBackward>)
# labels:  tensor([1, 0, 0, 0, 1])
# outputs size:  torch.Size([5, 1])
# labels size:  torch.Size([5])
# loss: tensor(0.2401, grad_fn=<MseLossBackward>)
# epoch 5000, loss 0.2401052713394165

# %% [markdown]
# ###Plotting Loss vs Epochs graph

# %%
fig,ax = plt.subplots(1)
plt.title('Loss vs Epochs')
ax.plot(losses)
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch')
plt.savefig('Loss_vs_Epoch.png')

# %% [markdown]
# ### Please answer the questions below to complete the experiment:

# %%
#@title How was the experiment? { run: "auto", form-width: "500px", display-mode: "form" }
Complexity = "Good, But Not Challenging for me" #@param ["Too Simple, I am wasting time", "Good, But Not Challenging for me", "Good and Challenging for me", "Was Tough, but I did it", "Too Difficult for me"]

# %%
#@title If it was very easy, what more you would have liked to have been added? If it was very difficult, what would you have liked to have been removed? { run: "auto", display-mode: "form" }
Additional = "test'\"" #@param {type:"string"}

# %%
#@title Can you identify the concepts from the lecture which this experiment covered? { run: "auto", vertical-output: true, display-mode: "form" }
Concepts = "Yes" #@param ["Yes", "No"]

# %%
#@title Run this cell to submit your notebook{ vertical-output: true }
try:
  if submission_id:
      return_id = submit_notebook()
      if return_id : submission_id =return_id
  else:
      print("Please complete the setup first.")
except NameError:
  print ("Please complete the setup first.")
