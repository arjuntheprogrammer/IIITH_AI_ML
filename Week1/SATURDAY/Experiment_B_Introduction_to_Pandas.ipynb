# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint

# %% [markdown]
# ## Learning Objective

# %% [markdown]
# At the end of this experiment, you will be able to :
#
# * Use Pandas Library

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Description

# %% [markdown]
# The dataset choosen for this exercise is a employee dataset. The dataset contains following information regarding a particular employee:
#
# * Emp ID
# * Name Prefix
# * First Name
# * Middle Initial
# * Last Name
# * Gender
# * E Mail
# * Father's Name
# * Mother's Name
# * Mother's Maiden Name
# * Date of Birth
# * Time of Birth
# * Age in Yrs
# *  Weight in Kgs
# * Date of Joining
# * Quarter of Joining
# * Half of Joining
# * Year of Joining
# * Month of Joining
# * Month Name of Joining
# * Short Month
# * Day of Joining
# * DOW of Joining
# * Short DOW
# * Age in Company (Years)
# * Salary
# * Last % Hike
# * SSN
# * Phone No
# * Place Name
# * CountyCity,
# * State
# * Zip
# * Region
# * User Name
# * Password
#
#
# Dataset is taken from http://eforexcel.com/wp/downloads-16-sample-csv-files-data-sets-for-testing/

# %% [markdown]
# ## Setup Steps

# %%
#@title Please enter your registration id to start: (e.g. P181900101) { run: "auto", display-mode: "form" }
Id = "P181902118" #@param {type:"string"}

# %%
#@title Please enter your password (normally your phone number) to continue: { run: "auto", display-mode: "form" }
password = "8860303743" #@param {type:"string"}

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython

ipython = get_ipython()
  
notebook="Experiment_B_Introduction_to_Pandas" #name of the notebook
Answer = "Ungraded"
def setup():
#  ipython.magic("sx pip3 install torch")
    ipython.magic("sx wget https://cdn.talentsprint.com/aiml/Experiment_related_data/Employee.csv")
    ipython.magic("sx wget https://cdn.talentsprint.com/aiml/Experiment_related_data/Large_employee.csv")
    from IPython.display import HTML, display
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():
    
    ipython.magic("notebook -e "+ notebook + ".ipynb")
    
    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword()}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:        
        print(r["err"])
        return None        
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getAnswer() and getComplexity() and getAdditional() and getConcepts():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional, 
              "concepts" : Concepts, "record_id" : submission_id, 
              "answer" : Answer, "id" : Id, "file_hash" : file_hash,
              "notebook" : notebook}

      r = requests.post(url, data = data)
      r = json.loads(r.text)
      print("Your submission is successful.")
      print("Ref Id:", submission_id)
      print("Date of submission: ", r["date"])
      print("Time of submission: ", r["time"])
      print("View your submissions: https://iiith-aiml.talentsprint.com/notebook_submissions")
      print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
      return submission_id
    else: submission_id
    

def getAdditional():
  try:
    if Additional: return Additional      
    else: raise NameError('')
  except NameError:
    print ("Please answer Additional Question")
    return None

def getComplexity():
  try:
    return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None
  
def getConcepts():
  try:
    return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None

def getAnswer():
  try:
    return Answer
  except NameError:
    print ("Please answer Question")
    return None

def getId():
  try: 
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup 
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()
    from IPython.display import HTML
    HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id))
  
else:
  print ("Please complete Id and Password cells before running setup")
# Out:
# <script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId=P181902118&recordId=1723"></script>
# Setup completed successfully

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### a) Load the dataset

# %%
dataset = "Employee.csv"

# %%
# Your Code Here
print(dataset)
import pandas as pd

df = pd.read_csv(dataset)
print(df[:5])
# Out:
# Employee.csv
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  677509        Drs.       Lois              H    Walker      F
# 1  940761         Ms.     Brenda              S  Robinson      F
# 2  428945         Dr.        Joe              W  Robinson      M
# 3  408351        Drs.      Diane              I     Evans      F
# 4  193819         Mr.   Benjamin              R   Russell      M
#
#                          E Mail     Father's Name       Mother's Name  \
# 0       lois.walker@hotmail.com     Donald Walker        Helen Walker
# 1     brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 2        joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
# 3         diane.evans@yahoo.com       Jason Evans      Michelle Evans
# 4  benjamin.russell@charter.net   Gregory Russell   Elizabeth Russell
#
#   Mother's Maiden Name       ...                SSN    Phone No.   \
# 0                Lewis       ...        467-99-4677  303-572-8492
# ...

# %% [markdown]
# ### b) Display first 5 entries from the dataset

# %%
# Your Code Here
print(df[:5])
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  677509        Drs.       Lois              H    Walker      F
# 1  940761         Ms.     Brenda              S  Robinson      F
# 2  428945         Dr.        Joe              W  Robinson      M
# 3  408351        Drs.      Diane              I     Evans      F
# 4  193819         Mr.   Benjamin              R   Russell      M
#
#                          E Mail     Father's Name       Mother's Name  \
# 0       lois.walker@hotmail.com     Donald Walker        Helen Walker
# 1     brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 2        joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
# 3         diane.evans@yahoo.com       Jason Evans      Michelle Evans
# 4  benjamin.russell@charter.net   Gregory Russell   Elizabeth Russell
#
#   Mother's Maiden Name       ...                SSN    Phone No.   \
# 0                Lewis       ...        467-99-4677  303-572-8492
# ...

# %% [markdown]
# ### c) How many  records are there in the dataset?

# %%
# Your Code Here
print("number of rows - ", df.shape[0])
# Out:
# number of rows -  100

# %% [markdown]
# ### d) How many columns are there in the dataset?

# %%
# Your Code Here
print("number of columns - ", df.shape[1])
# Out:
# number of columns -  37

# %% [markdown]
# ### e) Print the name of all the columns

# %%
# Your Code Here
print(df.columns.values)
# Out:
# ['Emp ID' 'Name Prefix' 'First Name' 'Middle Initial' 'Last Name' 'Gender'
#  'E Mail' "Father's Name" "Mother's Name" "Mother's Maiden Name"
#  'Date of Birth' 'Time of Birth' 'Age in Yrs.' 'Weight in Kgs.'
#  'Date of Joining' 'Quarter of Joining' 'Half of Joining'
#  'Year of Joining' 'Month of Joining' 'Month Name of Joining'
#  'Short Month' 'Day of Joining' 'DOW of Joining' 'Short DOW'
#  'Age in Company (Years)' 'Salary' 'Last % Hike' 'SSN' 'Phone No. '
#  'Place Name' 'County' 'City' 'State' 'Zip' 'Region' 'User Name'
#  'Password']

# %% [markdown]
# ### f) What is  the name of 20th column ?

# %%
# Your Code Here
cols = df.columns.values
print(cols[19])
# Out:
# Month Name of Joining

# %% [markdown]
# ### g) What is  the datatype of each column?

# %%
# Your Code Here
print(df.dtypes)
# Out:
# Emp ID                      int64
# Name Prefix                object
# First Name                 object
# Middle Initial             object
# Last Name                  object
# Gender                     object
# E Mail                     object
# Father's Name              object
# Mother's Name              object
# Mother's Maiden Name       object
# Date of Birth              object
# Time of Birth              object
# Age in Yrs.               float64
# Weight in Kgs.              int64
# Date of Joining            object
# Quarter of Joining         object
# Half of Joining            object
# Year of Joining             int64
# Month of Joining            int64
# Month Name of Joining      object
# Short Month                object
# Day of Joining              int64
# DOW of Joining             object
# Short DOW                  object
# Age in Company (Years)    float64
# Salary                      int64
# Last % Hike                object
# ...

# %% [markdown]
# ### h) Display the columns 4 to 9 for rows 7 to 13

# %%
# Your Code Here
print(df.iloc[7:14, 4:10])
# Out:
#     Last Name Gender                        E Mail      Father's Name  \
# 7      Murphy      F        carol.murphy@gmail.com      Eugene Murphy
# 8       Young      F       frances.young@gmail.com         Fred Young
# 9    Peterson      F  diana.peterson@hotmail.co.uk  Jonathan Peterson
# 10     Flores      M        ralph.flores@yahoo.com       Terry Flores
# 11  Alexander      M      jack.alexander@gmail.com   Samuel Alexander
# 12       King      F      melissa.king@comcast.net        Philip King
# 13     Watson      M        wayne.watson@gmail.com      Ronald Watson
#
#          Mother's Name Mother's Maiden Name
# 7     Katherine Murphy             Peterson
# 8        Lillian Young                 Diaz
# 9   Christina Peterson                 Ross
# 10     Michelle Flores                Moore
# 11    Sharon Alexander               Walker
# 12          Maria King                White
# 13     Margaret Watson                Hayes

# %% [markdown]
# ### i) Display all the rows after 50th row

# %%
# Your Code Here
print(df[50:])

# %% [markdown]
# ### j) Display the columns 10 to 12  for first 50 rows

# %%
# Your Code Here
print(df.iloc[:50, 10:13])
# Out:
#    Date of Birth Time of Birth  Age in Yrs.
# 0      3/29/1981   02:31:49 AM        36.36
# 1      7/31/1970   12:13:27 PM        47.02
# 2      6/16/1963   10:45:36 AM        54.15
# 3      12/4/1977   02:18:45 AM        39.67
# 4      4/17/1977   05:41:11 PM        40.31
# 5      9/27/1982   01:12:41 PM        34.86
# 6      6/13/1995   08:56:32 PM        22.14
# 7      6/30/1958   10:39:33 AM        59.12
# 8       6/9/1959   04:38:47 PM        58.18
# 9     11/13/1987   03:59:26 AM        29.73
# 10      2/5/1975   02:15:50 AM        42.50
# 11     5/19/1995   04:33:57 PM        22.21
# 12     2/24/1972   06:04:57 PM        45.45
# 13     6/26/1996   12:23:21 AM        21.10
# 14     2/23/1958   06:59:29 PM        59.47
# 15     8/22/1966   08:11:15 PM        50.97
# 16     5/18/1970   03:47:46 AM        47.23
# 17     12/5/1992   09:20:52 AM        24.66
# 18     7/15/1959   09:24:39 PM        58.08
# 19     10/4/1967   08:28:14 PM        49.85
# ...

# %% [markdown]
# ###  k) Display the information of the employees who have  joined in Quarter 1 and 4.

# %%
# Your Code Here
print(df[(df['Quarter of Joining'] == "Q1") | 
         (df['Quarter of Joining'] == "Q4")])
# Out:
#     Emp ID Name Prefix   First Name Middle Initial   Last Name Gender  \
# 0   677509        Drs.         Lois              H      Walker      F
# 7   380086        Mrs.        Carol              V      Murphy      F
# 9   162402        Hon.        Diana              T    Peterson      F
# 11  153989       Prof.         Jack              C   Alexander      M
# 12  386158        Mrs.      Melissa              Q        King      F
# 14  441771        Mrs.       Cheryl              O       Scott      F
# 17  214352         Ms.      Theresa              G         Lee      F
# 18  890290        Hon.        Julia              S       Scott      F
# 21  969580       Prof.      Matthew              L      Turner      M
# 22  426038        Hon.         Joan              C     Stewart      F
# 25  477253        Mrs.         Anne              L     Russell      F
# 26  263480        Hon.       Daniel              K      Cooper      M
# ...

# %% [markdown]
# ### l) How many people are from the southern region joined on Monday?

# %%
# Your Code Here
# print(df["DOW of Joining"][:1])
# print(df[df['Day of Joining'] == "Monday"])
# reg = df[df["Region"]=="South"]
# print(doj[:5], reg[:5] )
print(df[(df['DOW of Joining'] == "Monday") & (df["Region"]=="South")])
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 9   162402        Hon.      Diana              T  Peterson      F
# 15  528509        Hon.      Paula              G      Diaz      F
# 20  979607         Ms.      Carol              J   Edwards      F
# 30  329752        Hon.    Lillian              X     Brown      F
# 57  515103         Ms.       Anne              A     Perez      F
# 59  750173         Mr.    Antonio              R   Roberts      M
# 74  528673        Hon.       Paul              V    Watson      M
# 76  262382         Ms.     Cheryl              O    Miller      F
# 81  225925         Mr.       Paul              D    Cooper      M
#
#                           E Mail      Father's Name       Mother's Name  \
# 9   diana.peterson@hotmail.co.uk  Jonathan Peterson  Christina Peterson
# 15          paula.diaz@gmail.com          Alan Diaz        Kathryn Diaz
# 20         carol.edwards@msn.com      Shawn Edwards       Susan Edwards
# ...

# %% [markdown]
# ### m) Display the information of the employees who have more than 13 years experience in the company

# %%
# Your Code Here
# print(df['Age in Company (Years)'])
print(df[df['Age in Company (Years)'] > 13])
# Out:
#     Emp ID Name Prefix   First Name Middle Initial  Last Name Gender  \
# 0   677509        Drs.         Lois              H     Walker      F
# 3   408351        Drs.        Diane              I      Evans      F
# 7   380086        Mrs.        Carol              V     Murphy      F
# 8   477616        Hon.      Frances              B      Young      F
# 14  441771        Mrs.       Cheryl              O      Scott      F
# 15  528509        Hon.        Paula              G       Diaz      F
# 16  912990         Mr.       Joshua              T    Stewart      M
# 19  622406         Mr.       Thomas              Q      Lewis      M
# 24  560455         Ms.      Carolyn              V      Hayes      F
# 28  474599        Drs.        Maria              W     Walker      F
# 29  335732         Ms.       Brenda              M     Butler      F
# 31  893212         Ms.          Amy              B     Howard      F
# 35  333476        Hon.         Mary              P     Wilson      F
# ...

# %% [markdown]
# ### n) There is a lot of redundant data. For example, the information in the below columns is also available in the *Date of Joining * column.
#
#   1.   month of Joining
#   2.   year of Joining
#   3.   Day of Joining
#
# There could be other such columns containing redundant data. Please identify such columns and take appropriate action.
#
#
# You can refer to the below link :
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html

# %%
# Your Code Here
df = pd.read_csv(dataset)
print(df.columns.values)
# list1 = df.columns.values

# print((str(each) for each in df.columns.values))
# print(df[['Date of Joining', 'Quarter of Joining' ,'Half of Joining',
#  'Year of Joining', 'Month of Joining' ,'Month Name of Joining',
#  'Short Month' ,'Day of Joining', 'DOW of Joining' ,'Short DOW']][:2])

df=df.drop(['Year of Joining', 'Month of Joining','Day of Joining'],
        axis = 1)
print(df.columns.values)
# Out:
# ['Emp ID' 'Name Prefix' 'First Name' 'Middle Initial' 'Last Name' 'Gender'
#  'E Mail' "Father's Name" "Mother's Name" "Mother's Maiden Name"
#  'Date of Birth' 'Time of Birth' 'Age in Yrs.' 'Weight in Kgs.'
#  'Date of Joining' 'Quarter of Joining' 'Half of Joining'
#  'Year of Joining' 'Month of Joining' 'Month Name of Joining'
#  'Short Month' 'Day of Joining' 'DOW of Joining' 'Short DOW'
#  'Age in Company (Years)' 'Salary' 'Last % Hike' 'SSN' 'Phone No. '
#  'Place Name' 'County' 'City' 'State' 'Zip' 'Region' 'User Name'
#  'Password']
# ['Emp ID' 'Name Prefix' 'First Name' 'Middle Initial' 'Last Name' 'Gender'
#  'E Mail' "Father's Name" "Mother's Name" "Mother's Maiden Name"
#  'Date of Birth' 'Time of Birth' 'Age in Yrs.' 'Weight in Kgs.'
#  'Date of Joining' 'Quarter of Joining' 'Half of Joining'
#  'Month Name of Joining' 'Short Month' 'DOW of Joining' 'Short DOW'
#  'Age in Company (Years)' 'Salary' 'Last % Hike' 'SSN' 'Phone No. '
# ...

# %% [markdown]
# [link text](https://)### o) Remove "%" sign from the "Last % Hike" column values

# %% [markdown]
# you can refer the below link :
#
# https://stackoverflow.com/questions/52850192/python-extract-last-letter-of-a-string-from-a-pandas-column

# %%
# Your Code Here
df = pd.read_csv(dataset)
# print(df['Last % Hike'][:2])
# list= [x.strip()[-1] for x in df['Last % Hike']]
# print(list[:2])                       

# for index, x in enumerate(df['Last % Hike']):
#     df['Last % Hike'][index] = x[:-1]
# print(df['Last % Hike'][:2])

# new_df = df
# for i, row in df.iterrows():
# #   print(row['Last % Hike'])
#   new_df['Last % Hike'][i] = row['Last % Hike'][:-1]
# #   print(row['Last % Hike'])
# df = new_df
# print(df['Last % Hike'][:2])

df['Last % Hike'] = df["Last % Hike"].apply(lambda x: int(x.strip("%")))
print(df['Last % Hike'][:2])
# Out:
# 0    21
# 1    27
# Name: Last % Hike, dtype: int64

# %% [markdown]
# ### p) How many Female employees got hike more than 20% ?

# %%
# Your Code Here
print(len(df[df['Last % Hike']>20]))
# Out:
# 33

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# The dataset chosen for this exercise is the same as above dataset w.r.t to the column names, but, much larger in size. Out of these, there are 70 anomalous data points w.r.t salaries, age and experience (age in a company). Detect those and write them into a separate file.

# %%
large_dataset = "Large_employee.csv"
# Your Code Here
import pandas as pd
import numpy as np
from collections import Counter

df = pd.read_csv(large_dataset)
# print(df[:2])
columns = df.columns.values
row = df.values[0]
rowTypes = [type(x) for x in row]
print(columns)
print(list(zip(columns, rowTypes)))
c = Counter(df["Age in Yrs."])  
print(c.values())
# Out:
# ['Unnamed: 0' 'Emp ID' 'Name Prefix' 'First Name' 'Middle Initial'
#  'Last Name' 'Gender' 'E Mail' "Father's Name" "Mother's Name"
#  "Mother's Maiden Name" 'Date of Birth' 'Time of Birth' 'Age in Yrs.'
#  'Weight in Kgs.' 'Date of Joining' 'Quarter of Joining' 'Half of Joining'
#  'Year of Joining' 'Month of Joining' 'Month Name of Joining'
#  'Short Month' 'Day of Joining' 'DOW of Joining' 'Short DOW'
#  'Age in Company (Years)' 'Salary' 'Last % Hike' 'SSN' 'Phone No. '
#  'Place Name' 'County' 'City' 'State' 'Zip' 'Region' 'User Name'
#  'Password']
# ...

# %%
large_dataset = "Large_employee.csv"
import pandas as pd
df = pd.read_csv(large_dataset)
columns = df.columns.values

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
print(df.shape)

outliers=[]
def detect_outlier(data_1):
  threshold=3
  mean_1 = np.mean(data_1)
  std_1 =np.std(data_1)

  for y in data_1:
    print("y")
    z_score= (y - mean_1)/std_1 
    if np.abs(z_score) > threshold:
      outliers.append(y)
  return outliers


outlier_datapoints = detect_outlier(df['Salary'][:10]) #25 outliers
# outlier_datapoints = detect_outlier(df['Age in Yrs.']) #7 outliers
# print(outlier_datapoints)
# print(len(outliers))

# %% [markdown]
# ### Summary

# %% [markdown]
# To know more about Pandas, you can refer below link :
#
# https://www.machinelearningplus.com/python/101-pandas-exercises-python/

# %% [markdown]
# ## Please answer the questions below to complete the experiment:

# %%
#@title How was the experiment? { run: "auto", form-width: "500px", display-mode: "form" }
Complexity = " " #@param ["Too Simple, I am wasting time", "Good, But Not Challenging for me", "Good and Challenging for me", "Was Tough, but I did it", "Too Difficult for me"]

# %%
#@title If it was very easy, what more you would have liked to have been added? If it was very difficult, what would you have liked to have been removed? { run: "auto", display-mode: "form" }
Additional = "" #@param {type:"string"}

# %%
#@title Can you identify the concepts from the lecture which this experiment covered? { run: "auto", vertical-output: true, display-mode: "form" }
Concepts = " " #@param ["Yes", "No"]

# %%
#@title Run this cell to submit your notebook for grading { vertical-output: true }
try:
  if submission_id:
      return_id = submit_notebook()
      if return_id : submission_id =return_id
  else:
      print("Please complete the setup first.")
except NameError:
  print ("Please complete the setup first.")
