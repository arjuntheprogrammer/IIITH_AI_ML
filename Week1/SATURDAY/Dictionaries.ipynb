# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint
# ### Introduction to Python
# #### Dictionaries

# %% [markdown]
# ### Setup Steps

# %%
#@title Please enter your registration id to start: (e.g. P181900101) { run: "auto", display-mode: "form" }
Id = "P181902118" #@param {type:"string"}

# %%
#@title Please enter your password (normally your phone number) to continue: { run: "auto", display-mode: "form" }
password = "8860303743" #@param {type:"string"}

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython

ipython = get_ipython()
  
notebook="BLR_M0W1_Python_Dictionaries" #name of the notebook
Answer = "Ungraded"
def setup():
#  ipython.magic("sx pip3 install torch")  
    from IPython.display import HTML, display
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():
    
    ipython.magic("notebook -e "+ notebook + ".ipynb")
    
    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword()}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:        
        print(r["err"])
        return None        
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getAnswer() and getComplexity() and getAdditional() and getConcepts():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional, 
              "concepts" : Concepts, "record_id" : submission_id, 
              "answer" : Answer, "id" : Id, "file_hash" : file_hash,
              "notebook" : notebook}

      r = requests.post(url, data = data)
      r = json.loads(r.text)
      print("Your submission is successful.")
      print("Ref Id:", submission_id)
      print("Date of submission: ", r["date"])
      print("Time of submission: ", r["time"])
      print("View your submissions: https://iiith-aiml.talentsprint.com/notebook_submissions")
      print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
      return submission_id
    else: submission_id
    

def getAdditional():
  try:
    if Additional: return Additional      
    else: raise NameError('')
  except NameError:
    print ("Please answer Additional Question")
    return None

def getComplexity():
  try:
    return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None
  
def getConcepts():
  try:
    return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None

def getAnswer():
  try:
    return Answer
  except NameError:
    print ("Please answer Question")
    return None

def getId():
  try: 
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup 
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()
    from IPython.display import HTML
    HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id))
  
else:
  print ("Please complete Id and Password cells before running setup")
# Out:
# <script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId=P181902118&recordId=502"></script>
# Setup completed successfully

# %%
#Create a dictionary
capitals = {"INDIA" : "New Delhi", "BA" : "Washington DC", "UK" : "London" }

# %%
print(capitals)
print(capitals.pop('UK', "Not Available"))
print(capitals)
# Out:
# {'INDIA': 'New Delhi', 'BA': 'Washington DC'}
# Not Available
# {'INDIA': 'New Delhi', 'BA': 'Washington DC'}

# %%
#Retrive value of a key
capitals["BA"]
# Out:
# 'Washington DC'

# %%
#Retrive value of a key
capitals["INDIA"]
# Out:
# 'New Delhi'

# %%
#Case sensitive
capitals["India"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-ea9c8e39da4d> in <module>()
# ----> 1 capitals["India"]
#
# KeyError: 'India'

# %%
#Length of a dictionary
len(capitals)
# Out:
# 3

# %%
#Built-in function to get the keys
capitals.keys()
# Out:
# dict_keys(['INDIA', 'BA', 'UK'])

# %%
#Built-in function to get values 
capitals.values()
# Out:
# dict_values(['New Delhi', 'Washington DC', 'London'])

# %%
#Retrive all the key - value pairs
capitals.items()
# Out:
# dict_items([('INDIA', 'New Delhi'), ('BA', 'Washington DC'), ('UK', '')])

# %%
#Adding a key - value pair
capitals["UK"] = ""

# %%
#New length of dictionary
len(capitals)
# Out:
# 3

# %%
#Order of key-value pairs get changed
capitals
# Out:
# {'BA': 'Washington DC', 'INDIA': 'New Delhi', 'UK': ''}

# %%
capitals["AFGANISTAN"] = "Kabul"

# %%
#Update an existing dictionary
capitals["AFGANISTAN"] = "KABUL"

# %%
capitals
# Out:
# {'AFGANISTAN': 'KABUL', 'BA': 'Washington DC', 'INDIA': 'New Delhi', 'UK': ''}

# %%
#Dictionaries can contain tuples
capitals[(23,45)] = "Number"

# %%
capitals
# Out:
# {(23, 45): 'Number',
#  'AFGANISTAN': 'KABUL',
#  'BA': 'Washington DC',
#  'INDIA': 'New Delhi',
#  'UK': ''}

# %%
for k in capitals.keys():
  print ( capitals[k])
# Out:
# New Delhi
# Washington DC
#
# KABUL
# Number

# %%
for k in capitals.keys():
  print ( k , capitals[k])
# Out:
# INDIA New Delhi
# BA Washington DC
# UK
# AFGANISTAN KABUL
# (23, 45) Number

# %%
#Letter count
letterCount = {}

# %%
s = "TalentSprint is a digital platform designed to transform the lives of professionals in the new economy. Its blended bootcamps offer deeptech skills."

# %%
for ch in s :
  ch = ch.lower()
  if ch not in letterCount :
    letterCount[ch] = 1
  else :
    letterCount[ch] += 1

# %%
letterCount
# Out:
# {' ': 21,
#  '.': 2,
#  'a': 7,
#  'b': 2,
#  'c': 3,
#  'd': 6,
#  'e': 15,
#  'f': 6,
#  'g': 2,
#  'h': 3,
#  'i': 10,
#  'k': 1,
#  'l': 8,
#  'm': 4,
#  'n': 9,
#  'o': 11,
#  'p': 5,
#  'r': 6,
#  's': 12,
#  't': 12,
#  'v': 1,
#  'w': 1,
#  'y': 1}

# %%
letterCount.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-274491c2dbd4> in <module>()
# ----> 1 letterCount.keys()
#
# NameError: name 'letterCount' is not defined

# %% [markdown]
# ### Please answer the questions below to complete the experiment:

# %%
#@title How was the experiment? { run: "auto", form-width: "500px", display-mode: "form" }
Complexity = "Too Simple, I am wasting time" #@param ["Too Simple, I am wasting time", "Good, But Not Challenging for me", "Good and Challenging me", "Was Tough, but I did it", "Too Difficult for me"]

# %%
#@title If it was very easy, what more you would have liked to have been added? If it was very difficult, what would you have liked to have been removed? { run: "auto", display-mode: "form" }
Additional = " good" #@param {type:"string"}

# %%
#@title Can you identify the concepts from the lecture which this experiment covered? { run: "auto", vertical-output: true, display-mode: "form" }
Concepts = "Yes" #@param ["Yes", "No"]

# %%
#@title Run this cell to submit your notebook for grading { vertical-output: true }
try:
  if submission_id:
      return_id = submit_notebook()
      if return_id : submission_id =return_id
  else:
      print("Please complete the setup first.")
except NameError:
  print ("Please complete the setup first.")
# Out:
# Your submission is successful.
# Ref Id: 435
# Date of submission:  09 Mar 2019
# Time of submission:  09:28:32
# View your submissions: https://iiith-aiml.talentsprint.com/notebook_submissions
# For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.
